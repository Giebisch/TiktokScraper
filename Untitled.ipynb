# %%
from tiktokscraper.TiktokScraper import TiktokScraper

# create TiktokScraper object
TS = TiktokScraper()

# %%
await TS._initialize_browser(use_browser_cookies=True)

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
logging.debug("test")
# Out:
# DEBUG:root:test

# %%
videos = await TS.get_trending_videos()
videos
# Out:
# DEBUG:tiktokscraper.scraping:{'cursor': '0', 'extra': {'fatal_item_ids': [], 'logid': '20240414082405C50D00AA3303BCEFC745', 'now': 1713083046000}, 'hasMore': True, 'itemList': [{'author': {'avatarLarger': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/ab1697c873ec9992ce41701242eeb4f3~c5_1080x1080.jpeg?lk3s=a5d48078&x-expires=1713254400&x-signature=CT9MyiqceoWNZwyQfU107PNeu7E%3D', 'avatarMedium': 'https://p77-sign-va-lite.tiktokcdn.com/tos-maliva-avt-0068/ab1697c873ec9992ce41701242eeb4f3~c5_720x720.jpeg?lk3s=a5d48078&x-expires=1713254400&x-signature=g%2BQty48VlKHMiEOhgUbVL2Y2Q4U%3D', 'avatarThumb': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/ab1697c873ec9992ce41701242eeb4f3~c5_100x100.jpeg?lk3s=a5d48078&x-expires=1713254400&x-signature=P6dGrhk8SfVjgpDGbldymDOxMbU%3D', 'commentSetting': 0, 'downloadSetting': 0, 'duetSetting': 0, 'ftc': False, 'id': '6762938997860140038', 'isADVirtual': False, 'isEmbedBanned': False, 'nickname': 'Dilaraa.s💚', 'openFavorite': False, 'privateAccount': False, 'relation': 0, 'secUid': 'MS4wLjABAAAAXtM0g7BVqUhKfwVvk4mwy74A1D-2iVtFhKj5xmo2BxOUk2myUeiJertDdd51zuwq', 'secret': False, 'signature': 'The queen of green💚🫶🏼 Insta: @dilaraa.s\n\nMail: dilara@ins.gg', 'stitchSetting': 0, 'uniqueId': 'di1araa.s', 'verified': False}, 'authorStats': {'diggCount': 234900, 'followerCount': 8900000, 'followingCount': 884, 'friendCount': 0, 'heart': 241000000, 'heartCount': 241000000, 'videoCount': 1537}, 'collected': False, 'contents': [{'desc': '@Rezo die Tanzmaus 💙', 'textExtra': [{'awemeId': '', 'end': 5, 'hashtagName': '', 'isCommerce': False, 'secUid': 'MS4wLjABAAAAImpC8iLSLRXS7CCsDWxJulGzBTA7hk3F5LNzOLxcJhIoXOfU-5Jlw1juWJKg6OZN', 'start': 0, 'subType': 0, 'type': 0, 'userId': '6651546051420913670', 'userUniqueId': 'rezo'}]}], 'createTime': 1712590561, 'desc': '@Rezo die Tanzmaus 💙', 'digged': False, 'diversificationId': 10005, 'duetDisplay': 0, 'duetEnabled': True, 'forFriend': False, 'id': '7355520414216473888', 'itemCommentStatus': 0, 'item_control': {}, 'music': {'album': 'Megamix', 'authorName': 'Ráfaga', 'coverLarge': 'https://p77-sg.tiktokcdn.com/aweme/720x720/tos-alisg-v-2774/c550192141bc4a03b3cde92aea4dffe4.jpeg', 'coverMedium': 'https://p77-sg.tiktokcdn.com/aweme/200x200/tos-alisg-v-2774/c550192141bc4a03b3cde92aea4dffe4.jpeg', 'coverThumb': 'https://p77-sg.tiktokcdn.com/aweme/100x100/tos-alisg-v-2774/c550192141bc4a03b3cde92aea4dffe4.jpeg', 'duration': 60, 'id': '6863028513335674881', 'original': False, 'playUrl': 'https://sf16-ies-music-sg.tiktokcdn.com/obj/tos-alisg-ve-2774/fb7348e2c6d243078b0d8ce2db4e5c34', 'title': 'Mentirosa'}, 'officalItem': False, 'originalItem': False, 'privateItem': False, 'secret': False, 'shareEnabled': True, 'stats': {'collectCount': 18200, 'commentCount': 1417, 'diggCount': 305400, 'playCount': 2300000, 'shareCount': 2155}, 'statsV2': {'collectCount': '18173', 'commentCount': '1417', 'diggCount': '305400', 'playCount': '2300000', 'shareCount': '2155'}, 'stitchDisplay': 0, 'stitchEnabled': True, 'textExtra': [{'awemeId': '', 'end': 5, 'hashtagName': '', 'isCommerce': False, 'secUid': 'MS4wLjABAAAAImpC8iLSLRXS7CCsDWxJulGzBTA7hk3F5LNzOLxcJhIoXOfU-5Jlw1juWJKg6OZN', 'start': 0, 'subType': 0, 'type': 0, 'userId': '6651546051420913670', 'userUniqueId': 'rezo'}], 'video': {'bitrate': 1956139, 'bitrateInfo': [{'Bitrate': 1956139, 'CodecType': 'h264', 'GearName': 'normal_540_0', 'PlayAddr': {'DataSize': 3667762, 'FileCs': 'c:0-13954-5376', 'FileHash': 'c3195b2c7089cfbc4b885158814f7153', 'Uri': 'v0f044gc0000coa0sr7og65gb9sh24o0', 'UrlKey': 'v0f044gc0000coa0sr7og65gb9sh24o0_h264_540p_1956139', 'UrlList': ['https://v16-webapp-prime.tiktok.com/video/tos/useast2a/tos-useast2a-ve-0068-euttp/oAEhIGREQDAfuI0UgmfQPgtiPBF5JDFDAFasOg/?a=1988&bti=ODszNWYuMDE6&ch=0&cr=3&dr=0&lr=unwatermarked&cd=0%7C0%7C0%7C&cv=1&br=3820&bt=1910&cs=0&ds=6&ft=4fUEKMFx8Zmo0kdNu-4jVbTGupWrKsd.&mime_type=video_mp4&qs=0&rc=N2k0NDlmPGlkZDxnZ2VmZUBpMzdrPGo5cnUzcjMzZjczM0BeLzMuNS9gXmExMV9iYDItYSNsL3BfMm ...
# [<tiktokscraper.models.Video at 0x11047ead0>,
#  <tiktokscraper.models.Video at 0x11047c3d0>,
#  <tiktokscraper.models.Video at 0x1118d4f90>,
#  <tiktokscraper.models.Video at 0x111c9cd10>,
#  <tiktokscraper.models.Video at 0x111c9cb90>,
#  <tiktokscraper.models.Video at 0x111ca74d0>,
#  <tiktokscraper.models.Video at 0x111ca45d0>,
#  <tiktokscraper.models.Video at 0x111ca4090>,
#  <tiktokscraper.models.Video at 0x111ca4d10>,
#  <tiktokscraper.models.Video at 0x111ca6950>,
#  <tiktokscraper.models.Video at 0x1107b4610>,
#  <tiktokscraper.models.Video at 0x11041aad0>,
#  <tiktokscraper.models.Video at 0x111cf5b10>,
#  <tiktokscraper.models.Video at 0x111cf5e50>,
#  <tiktokscraper.models.Video at 0x111cf7710>,
#  <tiktokscraper.models.Video at 0x111cf6350>]
